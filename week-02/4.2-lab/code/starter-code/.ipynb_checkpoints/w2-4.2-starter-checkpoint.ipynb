# %%
import scipy as sp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm

# %%
# Generate a sequence of random variates, use the 
# random_state parameter which accepts an instance of 
# numpy.random.RandomState class, or an integer which is then used 
# to seed an internal RandomState object
# example: random = norm.rvs(size=5, random_state=1234)

random = norm.rvs(size=3, random_state=1234)
random
# Out:
# array([ 0.47143516, -1.19097569,  1.43270697])

# %%
# Use scipy.stats 'describe' to find: number of elements, min, max, 
# variance, skew, and kurtosis. Let's take a look.

# %%
random10 = np.random.randn(10)
random1000000 = np.random.randn(1000000)

# %%
stats.describe(random10)
# Out:
# DescribeResult(nobs=10, minmax=(-0.82348302604864509, 0.59219642224268032), mean=-0.038111804825750682, variance=0.22341818031977689, skewness=-0.3301367377862392, kurtosis=-1.2779676903622288)

# %%
stats.describe(random1000000)
# Out:
# DescribeResult(nobs=1000000, minmax=(-4.9214257889132744, 5.1244847408892564), mean=-0.00059941139283868476, variance=0.99980987213595818, skewness=-0.00021372653209899555, kurtosis=-0.007740563454375238)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.distplot(random1000000)
